# %% [markdown]
# <a href="https://colab.research.google.com/github/meghana507/ai-ml-practice-project/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print('numpy',np.__version__)
# Out:
# numpy 2.2.2

# %% [markdown]
# # 1.loading the dataset

# %%
X=np.array([[1,0,1,0],[1,0,1,1],[0,1,0,1]])
print('\n Input')
print(X)
print('/n shape of input',X.shape)
# Out:
#  Input
# <NumpyExtensionArray>
# [[1, 0, 1, 0], [1, 0, 1, 1], [0, 1, 0, 1]]
# Length: 3, dtype: object
# /n shape of input (3,)

# %%
import matplotlib
print('matplotlib',matplotlib.__version__)
# Out:
# matplotlib 3.10.0

# %%
X=X.T
print(X)
X.shape
# Out:
# <NumpyExtensionArray>
# [[1, 0, 1, 0], [1, 0, 1, 1], [0, 1, 0, 1]]
# Length: 3, dtype: object
# (3,)

# %%
import numpy as np

X = np.array([[1,0,1,0],
              [1,0,1,1],
              [0,1,0,1]], dtype=int)

print("\nInput")
print(X)
print("\nShape of input:", X.shape)
# Out:
# Input
# [[1 0 1 0]
#  [1 0 1 1]
#  [0 1 0 1]]
#
# Shape of input: (3, 4)

# %%
X=X.T
print(X)
X.shape
# Out:
# [[1 1 0]
#  [0 0 1]
#  [1 1 0]
#  [0 1 1]]
# (4, 3)

# %%
y=np.array([[1],
            [1],
            [0]])
y
y=y.T
y.shape
# Out:
# (1, 3)

# %% [markdown]
# # 2.Architecture of the model(#input,hidden,output)

# %%
inputlayer_neurons=X.shape[0]
hiddenlayer_neurons=3
output_neurons=1

# %%
X.shape
# Out:
# (4, 3)

# %% [markdown]
# # 3.Initializing the wights for all the layers

# %%
w_ih=np.random.uniform(size=(inputlayer_neurons,hiddenlayer_neurons))

# %%
w_ho=np.random.uniform(size=(hiddenlayer_neurons,output_neurons))

# %%
print(w_ih.shape)
print(w_ho.shape)
# Out:
# (4, 3)
# (3, 1)
