# %% [markdown]
# <a href="https://colab.research.google.com/github/meghana507/ai-ml-practice-project/blob/main/11_4_Converting_images_into_different_formats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Loading Required Libraries

# %%
# importing modules from skimage to read and display images
from skimage.io import imshow, imread, imsave
from skimage.color import rgb2gray, rgba2rgb
import numpy as np

# %% [markdown]
# ## Loading a RGB image

# %%
# reading the image using its path
image = imread('dog.jpg')

# %%
#checking shape of image
image.shape
# Out:
# (340, 453, 3)

# %%
# plotting the image
imshow(image)
# Out:
# /tmp/ipykernel_151/2733449316.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(image)

# %% [markdown]
# ## Loading RGBA image

# %%
image_rgba = imread('mid_alpha.png')
image_rgba.shape
# Out:
# (340, 453, 4)

# %%
imshow(image_rgba)
# Out:
# /tmp/ipykernel_151/257488254.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(image_rgba)

# %% [markdown]
# ## Converting RGBA to RGB

# %%
image_rgba = imread('mid_alpha.png')
image_rgba.shape
# Out:
# (340, 453, 4)

# %%
# converting rgba to rgb
image_rgb = rgba2rgb(image_rgba)
image_rgb.shape
# Out:
# (340, 453, 3)

# %%
imshow(image_rgb)
# Out:
# /tmp/ipykernel_151/2705084738.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(image_rgb)

# %% [markdown]
# ## Converting RGB to grayscale image

# %%
# converting rgb to gray
image_gray = rgb2gray(image)
image_gray.shape
# Out:
# (340, 453)

# %%
imshow(image_gray)
# Out:
# /tmp/ipykernel_151/1285382542.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(image_gray)

# %% [markdown]
# ## Challenge #2 - Loading RGB in Grayscale format

# %%
image_ = imread('dog.jpg', as_gray=True)
imshow(image_)
# Out:
# /tmp/ipykernel_151/931895349.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(image_)

# %%
image_ = imread('mid_alpha.png', as_gray=True)
print(image_.shape)
imshow(image_)
# Out:
# (340, 453)
# /tmp/ipykernel_151/2971166517.py:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(image_)
