# %% [markdown]
# <a href="https://colab.research.google.com/github/meghana507/ai-ml-practice-project/blob/main/Weight_Initialization_Techniques_in_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Steps to solve Emergency vs Non-Emergency vehicle classification
#
# <ol>1. Loading the dataset</ol>
# <ol>2. Pre-processing the data</ol>
# <ol>3. Creating training and validation set</ol>
# <ol>4. Defining the model architecture</ol>
# <ol><ol>Setting up the weight initialization technique</ol></ol>
# <ol>5. Compiling the model</ol>
# <ol>6. Training the model</ol>
# <ol>7. Evaluating model performance</ol>

# %% [markdown]
# ## 1. Loading the dataset

# %%
# import necessary libraries and functions
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# importing layers from keras
from keras.layers import Dense, InputLayer
from keras.models import Sequential
# importing adam optimizer from keras optimizer module
from keras.optimizers import Adam

# train_test_split to create training and validation set
from sklearn.model_selection import train_test_split
# accuracy_score to calculate the accuracy of predictions
from sklearn.metrics import accuracy_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# unzipping the Dataset.zip file
# !unzip /content/drive/MyDrive/Dataset.zip
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/Dataset.zip, /content/drive/MyDrive/Dataset.zip.zip or /content/drive/MyDrive/Dataset.zip.ZIP.

# %%
# reading the csv file
data = pd.read_csv('/content/emergency_classification.csv')

# %%
# defining the seed value
seed = 42

# %%
# looking at first five rows of the data
data.head()
# Out:
#   image_names  emergency_or_not
# 0       0.jpg                 1
# 1       1.jpg                 1
# 2       2.jpg                 1
# 3       3.jpg                 1
# 4       4.jpg                 1

# %%
import shutil
shutil.copytree('/content/drive/MyDrive/images/images', '/content/images')
# Out:
# '/content/images'

# %%
# load images and store it in numpy array

# empty list to store the images
X = []
# iterating over each image
for img_name in data.image_names:
    # loading the image using its name
    img = plt.imread('/content/images/' + img_name)
    # saving each image in the list
    X.append(img)

# converting the list of images into array
X=np.array(X)

# storing the target variable in separate variable
y = data.emergency_or_not.values

# %%
# shape of the images
X.shape
# Out:
# (2352, 224, 224, 3)

# %% [markdown]
# ## 2. Pre-processing the data

# %%
# converting 3 dimensional image to 1 dimensional image
X = X.reshape(X.shape[0], 224*224*3)
X.shape
# Out:
# (2352, 150528)

# %%
# minimum and maximum pixel values of images
X.min(), X.max()
# Out:
# (np.uint8(0), np.uint8(255))

# %%
# normalizing the pixel values
X = X / X.max()

# %%
# minimum and maximum pixel values of images after normalizing
X.min(), X.max()
# Out:
# (np.float64(0.0), np.float64(1.0))

# %% [markdown]
# ## 3. Creating training and validation set

# %%
# creating a training and validation set
X_train, X_valid, y_train, y_valid=train_test_split(X,y,test_size=0.3, random_state=seed)

# %%
# shape of training and validation set
(X_train.shape, y_train.shape), (X_valid.shape, y_valid.shape)
# Out:
# (((1646, 150528), (1646,)), ((706, 150528), (706,)))

# %% [markdown]
# ## 4. Defining the model architecture

# %% [markdown]
# ### Setting up the weight initialization technique

# %%
# importing different initialization techniques
from keras.initializers import random_normal, glorot_normal, he_normal

# %%
# defining the model architecture
model=Sequential()

model.add(InputLayer(input_shape=(224*224*3,)))
model.add(Dense(100, activation='sigmoid', kernel_initializer=he_normal(seed=seed)))
model.add(Dense(100, activation='sigmoid', kernel_initializer=he_normal(seed=seed)))
model.add(Dense(units=1, activation='sigmoid', kernel_initializer=he_normal(seed=seed)))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %% [markdown]
# ## 5. Compiling the model

# %%
# defining the adam optimizer and setting the learning rate as 10^-5
adam = Adam(learning_rate=1e-5)

# %%
# compiling the model

# defining loss as binary crossentropy
# defining optimizer as Adam
# defining metrics as accuracy

model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

# %% [markdown]
# ## 6. Training the model

# %%
# training the model for 50 epochs
model_history = model.fit(X_train, y_train, epochs=50, batch_size=128, validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 506ms/step - accuracy: 0.6309 - loss: 0.6653 - val_accuracy: 0.5722 - val_loss: 0.6612
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 696ms/step - accuracy: 0.6185 - loss: 0.6497 - val_accuracy: 0.6445 - val_loss: 0.6364
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 450ms/step - accuracy: 0.6682 - loss: 0.6250 - val_accuracy: 0.6742 - val_loss: 0.6200
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 14s 744ms/step - accuracy: 0.6877 - loss: 0.6087 - val_accuracy: 0.6827 - val_loss: 0.6098
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 656ms/step - accuracy: 0.6822 - loss: 0.6159 - val_accuracy: 0.6771 - val_loss: 0.6042
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 450ms/step - accuracy: 0.7089 - loss: 0.5955 - val_accuracy: 0.6799 - val_loss: 0.6027
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 619ms/step - accuracy: 0.6989 - loss: 0.5980 - val_accuracy: 0.6941 - val_loss: 0.5912
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 447ms/step - accuracy: 0.7212 - loss: 0.5815 - val_accuracy: 0.6884 - val_loss: 0.5880
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 632ms/step - accuracy: 0.7384 - loss: 0.5676 - val_accuracy: 0.6926 - val_loss: 0.5845
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 445ms/step - accuracy: 0.7436 - loss: 0.5627 - val_accuracy: 0.6926 - val_loss: 0.5782
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 569ms/step - accuracy: 0.7258 - loss: 0.5603 - val_accuracy: 0.6912 - val_loss: 0.5762
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 567ms/step - accuracy: 0.7471 - loss: 0.5467 - val_accuracy: 0.6912 - val_loss: 0.5744
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 485ms/step - accuracy: 0.7349 - loss: 0.5483 - val_accuracy: 0.7040 - val_loss: 0.5722
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 494ms/step - accuracy: 0.7487 - loss: 0.5517 - val_accuracy: 0.7025 - val_loss: 0.5699
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 555ms/step - accuracy: 0.7509 - loss: 0.5393 - val_accuracy: 0.7011 - val_loss: 0.5680
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 587ms/step - accuracy: 0.7501 - loss: 0.5362 - val_accuracy: 0.7040 - val_loss: 0.5669
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 518ms/step - accuracy: 0.7622 - loss: 0.5369 - val_accuracy: 0.7025 - val_loss: 0.5655
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 682ms/step - accuracy: 0.7566 - loss: 0.5344 - val_accuracy: 0.7040 - val_loss: 0.5649
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 656ms/step - accuracy: 0.7614 - loss: 0.5230 - val_accuracy: 0.7082 - val_loss: 0.5636
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 509ms/step - accuracy: 0.7662 - loss: 0.5213 - val_accuracy: 0.7040 - val_loss: 0.5612
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 620ms/step - accuracy: 0.7660 - loss: 0.5161 - val_accuracy: 0.7054 - val_loss: 0.5654
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 503ms/step - accuracy: 0.7693 - loss: 0.5158 - val_accuracy: 0.6969 - val_loss: 0.5714
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 14s 691ms/step - accuracy: 0.7780 - loss: 0.5112 - val_accuracy: 0.6997 - val_loss: 0.5709
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 520ms/step - accuracy: 0.7784 - loss: 0.5058 - val_accuracy: 0.7082 - val_loss: 0.5580
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 581ms/step - accuracy: 0.7691 - loss: 0.5082 - val_accuracy: 0.7040 - val_loss: 0.5570
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 471ms/step - accuracy: 0.7910 - loss: 0.4908 - val_accuracy: 0.6969 - val_loss: 0.5773
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 635ms/step - accuracy: 0.7829 - loss: 0.5020 - val_accuracy: 0.6856 - val_loss: 0.5823
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 462ms/step - accuracy: 0.7763 - loss: 0.5015 - val_accuracy: 0.6955 - val_loss: 0.5634
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 462ms/step - accuracy: 0.8185 - loss: 0.4715 - val_accuracy: 0.7125 - val_loss: 0.5534
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 13s 670ms/step - accuracy: 0.7850 - loss: 0.4964 - val_accuracy: 0.7110 - val_loss: 0.5525
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 620ms/step - accuracy: 0.7985 - loss: 0.4853 - val_accuracy: 0.7025 - val_loss: 0.5601
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 462ms/step - accuracy: 0.7892 - loss: 0.4871 - val_accuracy: 0.6997 - val_loss: 0.5691
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 510ms/step - accuracy: 0.7892 - loss: 0.4897 - val_accuracy: 0.7096 - val_loss: 0.5512
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 681ms/step - accuracy: 0.7986 - loss: 0.4746 - val_accuracy: 0.7195 - val_loss: 0.5494
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 511ms/step - accuracy: 0.8022 - loss: 0.4776 - val_accuracy: 0.7110 - val_loss: 0.5527
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 625ms/step - accuracy: 0.8137 - loss: 0.4661 - val_accuracy: 0.7082 - val_loss: 0.5531
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 618ms/step - accuracy: 0.7969 - loss: 0.4828 - val_accuracy: 0.7082 - val_loss: 0.5487
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 463ms/step - accuracy: 0.8209 - loss: 0.4596 - val_accuracy: 0.7096 - val_loss: 0.5536
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 562ms/step - accuracy: 0.8261 - loss: 0.4515 - val_accuracy: 0.7068 - val_loss: 0.5592
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 633ms/step - accuracy: 0.7986 - loss: 0.4737 - val_accuracy: 0.7082 - val_loss: 0.5518
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 512ms/step - accuracy: 0.8119 - loss: 0.4655 - val_accuracy: 0.7238 - val_loss: 0.5450
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 651ms/step - accuracy: 0.8160 - loss: 0.4583 - val_accuracy: 0.7210 - val_loss: 0.5444
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 511ms/step - accuracy: 0.8158 - loss: 0.4641 - val_accuracy: 0.7238 - val_loss: 0.5436
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 521ms/step - accuracy: 0.8224 - loss: 0.4512 - val_accuracy: 0.7224 - val_loss: 0.5427
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 688ms/step - accuracy: 0.8346 - loss: 0.4419 - val_accuracy: 0.7167 - val_loss: 0.5430
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 511ms/step - accuracy: 0.8409 - loss: 0.4368 - val_accuracy: 0.7025 - val_loss: 0.5570
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 495ms/step - accuracy: 0.8393 - loss: 0.4470 - val_accuracy: 0.7025 - val_loss: 0.5523
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 665ms/step - accuracy: 0.8291 - loss: 0.4367 - val_accuracy: 0.7167 - val_loss: 0.5429
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 511ms/step - accuracy: 0.8295 - loss: 0.4389 - val_accuracy: 0.7195 - val_loss: 0.5414
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 681ms/step - accuracy: 0.8390 - loss: 0.4483 - val_accuracy: 0.7181 - val_loss: 0.5403

# %% [markdown]
# ## 8. Evaluating model performance

# %%
y_pred = model.predict(X_valid)
y_pred = np.where(y_pred < 0.3, 0, 1)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step

# %%
# accuracy on validation set
print('Accuracy on validation set:', accuracy_score(y_valid, y_pred), '%')
# Out:
# Accuracy on validation set: 0.7039660056657224 %

# %%
 # summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# ### Comparison between random, glorot and he normal initialization
# ![alt text](https://drive.google.com/uc?id=1eneZC2OxBaDmU2ikhboiIADbuBksC18L)
