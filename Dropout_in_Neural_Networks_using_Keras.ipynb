# %% [markdown]
# <a href="https://colab.research.google.com/github/meghana507/ai-ml-practice-project/blob/main/Dropout_in_Neural_Networks_using_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x

# %% [markdown]
# # Steps to solve Emergency vs Non-Emergency vehicle classification problem using Dropout
#
# <ol>1. Loading the dataset</ol>
# <ol>2. Pre-processing the data</ol>
# <ol>3. Creating training and validation set</ol>
# <ol>4. Defining the model architecture</ol>
# <ol> <ol>* Adding dropout layer(s) </ol></ol>
# <ol>5. Compiling the model</ol>
# <ol>6. Training the model using Dropout</ol>
# <ol>7. Evaluating model performance</ol>

# %% [markdown]
# ## 1. Loading the dataset

# %%
# import necessary libraries and functions
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# importing layers from keras
from keras.layers import Dense, InputLayer
from keras.models import Sequential
# importing adam optimizer from keras optimizer module
from keras.optimizers import Adam

# train_test_split to create training and validation set
from sklearn.model_selection import train_test_split
# accuracy_score to calculate the accuracy of predictions
from sklearn.metrics import accuracy_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/Dataset.zip
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/Dataset.zip, /content/drive/MyDrive/Dataset.zip.zip or /content/drive/MyDrive/Dataset.zip.ZIP.

# %%
# reading the csv file
data = pd.read_csv('/content/emergency_classification.csv')

# %%
# create random number generator
seed = 42
rng = np.random.RandomState(seed)

# %%
# looking at first five rows of the data
data.head()
# Out:
#   image_names  emergency_or_not
# 0       0.jpg                 1
# 1       1.jpg                 1
# 2       2.jpg                 1
# 3       3.jpg                 1
# 4       4.jpg                 1

# %%
import shutil
shutil.copytree('/content/drive/MyDrive/images/images', '/content/images')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipykernel_224/3610874004.py in <cell line: 0>()
#       1 import shutil
# ----> 2 shutil.copytree('/content/drive/MyDrive/images/images', '/content/images')
#       3
#
# /usr/lib/python3.12/shutil.py in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     598     with os.scandir(src) as itr:
#     599         entries = list(itr)
# --> 600     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     601                      ignore=ignore, copy_function=copy_function,
#     602                      ignore_dangling_symlinks=ignore_dangling_symlinks,
#
# /usr/lib/python3.12/shutil.py in _copytree(entries, src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     496         ignored_names = ()
#     497
# --> 498     os.makedirs(dst, exist_ok=dirs_exist_ok)
#     499     errors = []
#     500     use_srcentry = copy_function is copy2 or copy_function is copy
#
# /usr/lib/python3.12/os.py in makedirs(name, mode, exist_ok)
#
# FileExistsError: [Errno 17] File exists: '/content/images'

# %%
# load images and store it in numpy array

# empty list to store the images
X = []
# iterating over each image
for img_name in data.image_names:
    # loading the image using its name
    img = plt.imread('/content/images/' + img_name)
    # saving each image in the list
    X.append(img)

# converting the list of images into array
X=np.array(X)

# storing the target variable in separate variable
y = data.emergency_or_not.values

# %% [markdown]
# ## 2. Pre-processing the data

# %%
# converting 3 dimensional image to 1 dimensional image
X = X.reshape(X.shape[0], 224*224*3)
X.shape
# Out:
# (2352, 150528)

# %%
# normalizing the pixel values
X = X / X.max()

# minimum and maximum pixel values of images after normalizing
X.min(), X.max()
# Out:
# (np.float64(0.0), np.float64(1.0))

# %% [markdown]
# ## 3. Creating training and validation set

# %%
# creating a training and validation set
X_train, X_valid, y_train, y_valid=train_test_split(X,y,test_size=0.3, random_state=seed)

# %%
# shape of training and validation set
(X_train.shape, y_train.shape), (X_valid.shape, y_valid.shape)
# Out:
# (((1646, 150528), (1646,)), ((706, 150528), (706,)))

# %% [markdown]
# ## 4. Defining the model architecture
#
# ### <ol>Adding dropout layer(s)</ol>

# %%
# importing the dropout layer
from keras.layers import Dropout

# %%
# defining the model architecture with dropout layer
model=Sequential()

model.add(InputLayer(input_shape=(224*224*3,)))
model.add(Dense(100, activation='sigmoid'))
model.add(Dropout(rate=0.5))
model.add(Dense(100, activation='sigmoid'))
model.add(Dropout(rate=0.5))
model.add(Dense(units=1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %% [markdown]
# ## 5. Compiling the model

# %%
# defining the adam optimizer and setting the learning rate as 10^-5
adam = Adam(learning_rate=1e-5)

# %%
# compiling the model

# defining loss as binary crossentropy
# defining optimizer as Adam
# defining metrics as accuracy

model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

# %% [markdown]
# ## 6. Training the model using Dropout

# %%
# training the model for 100 epochs

model_history = model.fit(X_train, y_train, epochs=100, batch_size=128,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 703ms/step - accuracy: 0.5371 - loss: 0.7691 - val_accuracy: 0.5609 - val_loss: 0.6682
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 486ms/step - accuracy: 0.5284 - loss: 0.7331 - val_accuracy: 0.5666 - val_loss: 0.6589
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 682ms/step - accuracy: 0.5839 - loss: 0.6938 - val_accuracy: 0.5878 - val_loss: 0.6498
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 498ms/step - accuracy: 0.5892 - loss: 0.6845 - val_accuracy: 0.6346 - val_loss: 0.6402
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 499ms/step - accuracy: 0.6017 - loss: 0.6699 - val_accuracy: 0.6416 - val_loss: 0.6366
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 668ms/step - accuracy: 0.5896 - loss: 0.6778 - val_accuracy: 0.6459 - val_loss: 0.6321
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 498ms/step - accuracy: 0.6059 - loss: 0.6798 - val_accuracy: 0.6459 - val_loss: 0.6306
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 451ms/step - accuracy: 0.5899 - loss: 0.6899 - val_accuracy: 0.6530 - val_loss: 0.6273
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 654ms/step - accuracy: 0.5817 - loss: 0.7031 - val_accuracy: 0.6572 - val_loss: 0.6247
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 493ms/step - accuracy: 0.5882 - loss: 0.6857 - val_accuracy: 0.6671 - val_loss: 0.6187
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 678ms/step - accuracy: 0.5916 - loss: 0.6981 - val_accuracy: 0.6700 - val_loss: 0.6175
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 508ms/step - accuracy: 0.6303 - loss: 0.6488 - val_accuracy: 0.6686 - val_loss: 0.6137
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s
100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 451ms/step - accuracy: 0.7385 - loss: 0.5385 - val_accuracy: 0.7054 - val_loss: 0.5684
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 514ms/step - accuracy: 0.7428 - loss: 0.5165 - val_accuracy: 0.7238 - val_loss: 0.5613
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 650ms/step - accuracy: 0.7421 - loss: 0.5454 - val_accuracy: 0.7224 - val_loss: 0.5590
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 454ms/step - accuracy: 0.7571 - loss: 0.5265 - val_accuracy: 0.7181 - val_loss: 0.5551
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 602ms/step - accuracy: 0.7548 - loss: 0.5033 - val_accuracy: 0.7181 - val_loss: 0.5570
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 532ms/step - accuracy: 0.7654 - loss: 0.5082 - val_accuracy: 0.7252 - val_loss: 0.5592
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 560ms/step - accuracy: 0.7535 - loss: 0.5315 - val_accuracy: 0.7082 - val_loss: 0.5499
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 10s 502ms/step - accuracy: 0.7531 - loss: 0.5246 - val_accuracy: 0.7125 - val_loss: 0.5515
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 503ms/step - accuracy: 0.7537 - loss: 0.5210 - val_accuracy: 0.7195 - val_loss: 0.5557
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 645ms/step - accuracy: 0.7538 - loss: 0.5322 - val_accuracy: 0.7125 - val_loss: 0.5645
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 455ms/step - accuracy: 0.7683 - loss: 0.4936 - val_accuracy: 0.7110 - val_loss: 0.5497
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 505ms/step - accuracy: 0.7591 - loss: 0.5066 - val_accuracy: 0.7082 - val_loss: 0.5478
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 687ms/step - accuracy: 0.7792 - loss: 0.5044 - val_accuracy: 0.7082 - val_loss: 0.5643
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 457ms/step - accuracy: 0.7577 - loss: 0.5092 - val_accuracy: 0.7238 - val_loss: 0.5560
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 9s 655ms/step - accuracy: 0.7663 - loss: 0.4977 - val_accuracy: 0.7210 - val_loss: 0.5528
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 455ms/step - accuracy: 0.7472 - loss: 0.5090 - val_accuracy: 0.7110 - val_loss: 0.5468
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 647ms/step - accuracy: 0.7620 - loss: 0.5053 - val_accuracy: 0.7195 - val_loss: 0.5534
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 458ms/step - accuracy: 0.7791 - loss: 0.4918 - val_accuracy: 0.7181 - val_loss: 0.5438
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 515ms/step - accuracy: 0.7366 - loss: 0.5276 - val_accuracy: 0.7238 - val_loss: 0.5512
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 12s 663ms/step - accuracy: 0.7840 - loss: 0.4870 - val_accuracy: 0.7181 - val_loss: 0.5533

# %% [markdown]
# ## 7. Evaluating model performance

# %%
y_pred = model.predict(X_valid)
y_pred = np.where(y_pred <0.3, 0, 1)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step

# %%
# accuracy on validation set
print('Accuracy on validation set:', accuracy_score(y_valid, y_pred), '%')
# Out:
# Accuracy on validation set: 0.7138810198300283 %

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# ![alt text](https://drive.google.com/uc?id=1pEBFo1GkfKsvWtKTKinqYVSxOGy1M4ie)
