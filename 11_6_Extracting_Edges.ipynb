# %% [markdown]
# <a href="https://colab.research.google.com/github/meghana507/ai-ml-practice-project/blob/main/11_6_Extracting_Edges.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Loading Required Libraries and Image

# %%
#importing the required libraries
from skimage.io import imread, imshow
from skimage.filters import sobel_h,prewitt_h,prewitt_v,sobel_v

# %%
#reading the image and plotting it
image = imread('dog.jpg', as_gray=True)
imshow(image,cmap='gray')
# Out:
# /tmp/ipykernel_599/1284318169.py:3: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(image,cmap='gray')

# %%
#checking the shape of the image
image.shape
# Out:
# (340, 453)

# %% [markdown]
# ## Sobel Kernel

# %%
#calculating the horizontal edges using sobel kernel
edges_sobel_horizontal = sobel_h(image)

#calculating the vertical edges using soble kernel
edges_sobel_vertical = sobel_v(image)

# %%
#plotting the sobel horizontal edges
imshow(edges_sobel_horizontal,cmap='gray')
# Out:
# /tmp/ipykernel_599/4088487502.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(edges_sobel_horizontal,cmap='gray')

# %%
#plotting the sobel vertical edges
imshow(edges_sobel_vertical,cmap='gray')
# Out:
# /tmp/ipykernel_599/3500731775.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(edges_sobel_vertical,cmap='gray')

# %% [markdown]
# ## Prewitt Kernel

# %%
#calculating horizontal edges using prewitt kernel
edges_prewitt_horizontal = prewitt_h(image)

#calculating vertical edges using prewitt kernel
edges_prewitt_vertical = prewitt_v(image)

# %%
#plotting prewitt horizontal edges
imshow(edges_prewitt_horizontal,cmap='gray')
# Out:
# /tmp/ipykernel_599/3303906747.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(edges_prewitt_horizontal,cmap='gray')

# %%
#plotting prewitt vertical edges
imshow(edges_prewitt_vertical,cmap='gray')
# Out:
# /tmp/ipykernel_599/2668206504.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(edges_prewitt_vertical,cmap='gray')
