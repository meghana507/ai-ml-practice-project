# %% [markdown]
# <a href="https://colab.research.google.com/github/meghana507/ai-ml-practice-project/blob/main/13_10_Batch_Normalization_in_Neural_Networks_using_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %% [markdown]
# # Steps to solve Emergency vs Non-Emergency vehicle classification problem using Batch Normalization
#
# <ol>1. Loading the dataset</ol>
# <ol>2. Pre-processing the data</ol>
# <ol>3. Creating training and validation set</ol>
# <ol>4. Defining the model architecture</ol>
# <ol> <ol>* Adding batch normalization layer(s) </ol></ol>
# <ol>5. Compiling the model</ol>
# <ol>6. Training the model</ol>
# <ol>7. Evaluating model performance</ol>

# %% [markdown]
# ## 1. Loading the dataset

# %%
# import necessary libraries and functions
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# importing layers from keras
from keras.layers import Dense, InputLayer
from keras.models import Sequential
# importing adam optimizer from keras optimizer module
from keras.optimizers import Adam

# train_test_split to create training and validation set
from sklearn.model_selection import train_test_split
# accuracy_score to calculate the accuracy of predictions
from sklearn.metrics import accuracy_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/Dataset.zip
# Out:
# Archive:  /content/drive/MyDrive/Dataset.zip
# replace Dataset/emergency_classification.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# reading the csv file
data = pd.read_csv('/content/emergency_classification.csv')

# %%
# create random number generator
seed = 42

# %%
import shutil
shutil.copytree("/content/drive/MyDrive/images/images",'/content/images', dirs_exist_ok=True)
# Out:
# '/content/images'

# %%
# load images and store it in numpy array

# empty list to store the images
X = []
# iterating over each image
for img_name in data.image_names:
    # loading the image using its name
    img = plt.imread('/content/images/' + img_name)
    # saving each image in the list
    X.append(img)

# converting the list of images into array
X=np.array(X)

# storing the target variable in separate variable
y = data.emergency_or_not.values

# %% [markdown]
# ## 2. Pre-processing the data

# %%
# converting 3 dimensional image to 1 dimensional image
X = X.reshape(X.shape[0], 224*224*3)
X.shape
# Out:
# (2352, 150528)

# %%
# normalizing the pixel values
X = X / X.max()

# minimum and maximum pixel values of images after normalizing
X.min(), X.max()
# Out:
# (np.float64(0.0), np.float64(1.0))

# %% [markdown]
# ## 3. Creating training and validation set

# %%
# creating a training and validation set
X_train, X_valid, y_train, y_valid=train_test_split(X,y,test_size=0.3, random_state=seed)

# %%
# shape of training and validation set
(X_train.shape, y_train.shape), (X_valid.shape, y_valid.shape)
# Out:
# (((1646, 150528), (1646,)), ((706, 150528), (706,)))

# %%
from keras.layers import BatchNormalization

# %% [markdown]
# ## 4. Defining the model architecture
#
# ### <ol>With Batch Normalization</ol>

# %%
# defining the model architecture
# defining the model architecture and adding batch normalization layers
model=Sequential()

model.add(InputLayer(input_shape=(224*224*3,)))
model.add(Dense(100, activation='sigmoid'))
model.add(Dense(100, activation='sigmoid'))
model.add(BatchNormalization())
model.add(Dense(units=1, activation='sigmoid'))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 100)            │    15,052,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 100)            │           400 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,063,501 (57.46 MB)
#  Trainable params: 15,063,301 (57.46 MB)
#  Non-trainable params: 200 (800.00 B)

# %% [markdown]
# ## 5. Compiling the model

# %%
# defining the adam optimizer and setting the learning rate as 10^-5
adam = Adam(learning_rate=1e-5)

# %%
# compiling the model

# defining loss as binary crossentropy
# defining optimizer as Adam
# defining metrics as accuracy

model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])

# %% [markdown]
# ## 6. Training the model

# %%
# training the model for 50 epochs

model_history = model.fit(X_train, y_train, epochs=50, batch_size=128,validation_data=(X_valid,y_valid))
# Out:
# Epoch 1/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 8s 346ms/step - accuracy: 0.6032 - loss: 0.7142 - val_accuracy: 0.4391 - val_loss: 0.8555
# Epoch 2/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.7385 - loss: 0.5406 - val_accuracy: 0.4391 - val_loss: 0.8246
# Epoch 3/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.7776 - loss: 0.4860 - val_accuracy: 0.4391 - val_loss: 0.8144
# Epoch 4/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.8086 - loss: 0.4318 - val_accuracy: 0.4391 - val_loss: 0.7855
# Epoch 5/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - accuracy: 0.8477 - loss: 0.3807 - val_accuracy: 0.4391 - val_loss: 0.7717
# Epoch 6/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.8933 - loss: 0.3280 - val_accuracy: 0.4391 - val_loss: 0.7818
# Epoch 7/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9026 - loss: 0.2975 - val_accuracy: 0.4391 - val_loss: 0.7804
# Epoch 8/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.9135 - loss: 0.2720 - val_accuracy: 0.4391 - val_loss: 0.7464
# Epoch 9/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9404 - loss: 0.2403 - val_accuracy: 0.4391 - val_loss: 0.7325
# Epoch 10/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9583 - loss: 0.2107 - val_accuracy: 0.4391 - val_loss: 0.7194
# Epoch 11/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.9534 - loss: 0.1939 - val_accuracy: 0.4476 - val_loss: 0.6940
# Epoch 12/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9727 - loss: 0.1788 - val_accuracy: 0.4391 - val_loss: 0.7167
# Epoch 13/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - accuracy: 0.9762 - loss: 0.1599 - val_accuracy: 0.4476 - val_loss: 0.7003
# Epoch 14/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 122ms/step - accuracy: 0.9795 - loss: 0.1499 - val_accuracy: 0.5581 - val_loss: 0.6599
# Epoch 15/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 112ms/step - accuracy: 0.9912 - loss: 0.1361 - val_accuracy: 0.4476 - val_loss: 0.7079
# Epoch 16/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.9879 - loss: 0.1222 - val_accuracy: 0.5425 - val_loss: 0.6575
# Epoch 17/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.9872 - loss: 0.1159 - val_accuracy: 0.4915 - val_loss: 0.6767
# Epoch 18/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9929 - loss: 0.1049 - val_accuracy: 0.5510 - val_loss: 0.6481
# Epoch 19/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9962 - loss: 0.0904 - val_accuracy: 0.6020 - val_loss: 0.6405
# Epoch 20/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.9990 - loss: 0.0886 - val_accuracy: 0.6799 - val_loss: 0.6240
# Epoch 21/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9943 - loss: 0.0812 - val_accuracy: 0.6360 - val_loss: 0.6258
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.9972 - loss: 0.0760 - val_accuracy: 0.6048 - val_loss: 0.6299
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9983 - loss: 0.0734 - val_accuracy: 0.7068 - val_loss: 0.6015
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.9978 - loss: 0.0695 - val_accuracy: 0.6643 - val_loss: 0.6115
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9976 - loss: 0.0672 - val_accuracy: 0.7096 - val_loss: 0.5902
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.9984 - loss: 0.0604 - val_accuracy: 0.7394 - val_loss: 0.5655
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - accuracy: 0.9957 - loss: 0.0598 - val_accuracy: 0.7578 - val_loss: 0.5632
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9993 - loss: 0.0558 - val_accuracy: 0.7139 - val_loss: 0.5739
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - accuracy: 0.9978 - loss: 0.0545 - val_accuracy: 0.7408 - val_loss: 0.5570
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - accuracy: 0.9971 - loss: 0.0510 - val_accuracy: 0.7535 - val_loss: 0.5486
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9975 - loss: 0.0521 - val_accuracy: 0.7139 - val_loss: 0.5601
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.9959 - loss: 0.0505 - val_accuracy: 0.6544 - val_loss: 0.5964
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9947 - loss: 0.0545 - val_accuracy: 0.7337 - val_loss: 0.5406
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9995 - loss: 0.0423 - val_accuracy: 0.7465 - val_loss: 0.5316
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.9984 - loss: 0.0401 - val_accuracy: 0.7465 - val_loss: 0.5215
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.9980 - loss: 0.0361 - val_accuracy: 0.7620 - val_loss: 0.5171
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.9967 - loss: 0.0378 - val_accuracy: 0.7521 - val_loss: 0.5161
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.9968 - loss: 0.0360 - val_accuracy: 0.6912 - val_loss: 0.5888
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9958 - loss: 0.0377 - val_accuracy: 0.7380 - val_loss: 0.5319
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.9956 - loss: 0.0348 - val_accuracy: 0.7578 - val_loss: 0.5173
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.9987 - loss: 0.0300 - val_accuracy: 0.7521 - val_loss: 0.5159
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9989 - loss: 0.0304 - val_accuracy: 0.7295 - val_loss: 0.5307
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.9951 - loss: 0.0358 - val_accuracy: 0.7521 - val_loss: 0.5246
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.9976 - loss: 0.0322 - val_accuracy: 0.7011 - val_loss: 0.6145
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.9976 - loss: 0.0298 - val_accuracy: 0.7493 - val_loss: 0.5364
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 0.9984 - loss: 0.0285 - val_accuracy: 0.7550 - val_loss: 0.5366
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - accuracy: 0.9936 - loss: 0.0312 - val_accuracy: 0.7422 - val_loss: 0.5816
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.9988 - loss: 0.0243 - val_accuracy: 0.7224 - val_loss: 0.5778
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9961 - loss: 0.0256 - val_accuracy: 0.7309 - val_loss: 0.5849
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9969 - loss: 0.0266 - val_accuracy: 0.7450 - val_loss: 0.5666

# %% [markdown]
# ## 7. Evaluating model performance

# %%
y_pred = model.predict(X_valid)[:,0]
y_pred = np.where(y_pred < 0.5, 0, 1)
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step

# %%
# accuracy on validation set
print('Accuracy on validation set:', accuracy_score(y_valid, y_pred), '%')
# Out:
# Accuracy on validation set: 0.7450424929178471 %

# %%
# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()
