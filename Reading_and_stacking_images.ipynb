# %% [markdown]
# <a href="https://colab.research.google.com/github/meghana507/ai-ml-practice-project/blob/main/Reading_and_stacking_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # structure of notebook
# # 1.Loading Images
# ## grayscale image
# ## RGB image
# ## RGBA image
# ## MRI image
# # 2.loading multiple images
# # 3.Resizing and saving images

# %%
import skimage
from skimage.io import imshow,imread,imsave
from skimage.transform import resize
import numpy as np

# %%
print("skimage version",skimage.__version__)
# Out:
# skimage version 0.25.2

# %% [markdown]
# # Loading Grayscale image

# %%
image_gray=imread('/content/grayscale.jpg')

# %%
image_gray.shape
# Out:
# (183, 195, 3)

# %%
image_gray
# Out:
# array([[[ 97,  97,  97],
#         [ 98,  98,  98],
#         [ 98,  98,  98],
#         ...,
#         [150, 150, 150],
#         [150, 150, 150],
#         [150, 150, 150]],
#
#        [[ 98,  98,  98],
#         [ 98,  98,  98],
#         [ 98,  98,  98],
#         ...,
#         [151, 151, 151],
#         [151, 151, 151],
#         [151, 151, 151]],
#
#        [[ 99,  99,  99],
#         [ 99,  99,  99],
#         [ 99,  99,  99],
#         ...,
#         [154, 154, 154],
#         [154, 154, 154],
#         [154, 154, 154]],
#
#        ...,
#
#        [[ 40,  40,  40],
#         [ 42,  42,  42],
#         [ 40,  40,  40],
#         ...,
#         [ 79,  79,  79],
#         [ 79,  79,  79],
#         [ 80,  80,  80]],
#
#        [[ 42,  42,  42],
#         [ 44,  44,  44],
#         [ 42,  42,  42],
#         ...,
#         [ 73,  73,  73],
#         [ 71,  71,  71],
#         [ 68,  68,  68]],
#
#        [[ 45,  45,  45],
#         [ 47,  47,  47],
#         [ 45,  45,  45],
# ...

# %%
imshow(image_gray)
# Out:
# /tmp/ipykernel_451/1285382542.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(image_gray)

# %% [markdown]
# # Loading a RGB image

# %%
image=imread('/content/dog.jpg')
image.shape
image
# Out:
# array([[[ 77,  95,  57],
#         [ 78,  96,  58],
#         [ 78,  96,  58],
#         ...,
#         [ 75,  95,  58],
#         [ 74,  94,  57],
#         [ 73,  93,  56]],
#
#        [[ 78,  96,  58],
#         [ 78,  96,  58],
#         [ 78,  96,  58],
#         ...,
#         [ 75,  95,  58],
#         [ 74,  94,  57],
#         [ 73,  93,  56]],
#
#        [[ 78,  96,  58],
#         [ 78,  96,  58],
#         [ 79,  97,  59],
#         ...,
#         [ 75,  95,  58],
#         [ 74,  94,  57],
#         [ 73,  93,  56]],
#
#        ...,
#
#        [[ 87,  88,  56],
#         [ 81,  82,  50],
#         [ 77,  78,  46],
#         ...,
#         [ 99,  95,  50],
#         [104,  98,  50],
#         [104,  96,  49]],
#
#        [[ 81,  85,  52],
#         [ 76,  80,  47],
#         [ 74,  78,  45],
#         ...,
#         [ 99,  95,  50],
#         [105,  99,  51],
#         [107,  99,  52]],
#
#        [[ 77,  81,  48],
#         [ 74,  78,  45],
#         [ 74,  78,  45],
# ...

# %% [markdown]
# # printing different channels of RGB

# %%
imshow(image)
# Out:
# /tmp/ipykernel_451/3355601266.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(image)

# %%
red_filter=[1,0,0]
imshow(image*red_filter)
# Out:
# /tmp/ipykernel_451/175983772.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(image*red_filter)
# /usr/local/lib/python3.12/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
green_filter=[0,1,0]
imshow(image*green_filter)
# Out:
# /tmp/ipykernel_451/24733220.py:2: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(image*green_filter)
# /usr/local/lib/python3.12/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:158: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
imshow(image[:,:,0],cmap='Reds')
# Out:
# /tmp/ipykernel_451/2580572759.py:1: FutureWarning: `imshow` is deprecated since version 0.25 and will be removed in version 0.27. Please use `matplotlib`, `napari`, etc. to visualize images.
#   imshow(image[:,:,0],cmap='Reds')

# %% [markdown]
# # Loading RGBA image

# %%
image_rgba=imread('/content/rgba.jpg')

# %%
image_rgba.shape
# Out:
# (148, 264, 3)
